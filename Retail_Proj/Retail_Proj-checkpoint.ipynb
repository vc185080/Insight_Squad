# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from prettytable import PrettyTable
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules, fpgrowth

# %%
main_data = pd.read_csv("C:\\Users\\vc185080\\Downloads\\ECommerce_consumer_behaviour\\ECommerce_consumer_behaviour.csv")
df = main_data.copy()
df.shape
# Out:
# (2019501, 12)

# %%
#df.info()
df['product_name'].unique()
# Out:
# array(['baking ingredients', 'soy lactosefree', 'butter',
#        'fresh vegetables', 'yogurt', 'canned meals beans',
#        'poultry counter', 'ice cream ice', 'fresh fruits', 'milk',
#        'packaged cheese', 'bread', 'tea', 'bakery desserts',
#        'frozen breakfast', 'cereal', 'eggs', 'buns rolls', 'cream',
#        'water seltzer sparkling water', 'pickled goods olives',
#        'packaged poultry', 'other creams cheeses',
#        'honeys syrups nectars', 'coffee', 'refrigerated',
#        'energy granola bars', 'soft drinks', 'latino foods',
#        'plates bowls cups flatware', 'paper goods', 'oral hygiene',
#        'diapers wipes', 'food storage', 'nuts seeds dried fruit', 'soap',
#        'packaged vegetables fruits', 'hot dogs bacon sausage',
#        'lunch meat', 'chips pretzels', 'meat counter',
#        'fresh dips tapenades', 'prepared soups salads', 'condiments',
#        'juice nectars', 'canned fruit applesauce',
#        'preserved dips spreads', 'packaged produce',
#        'canned jarred vegetables', 'fresh pasta', 'pasta sauce',
#        'frozen produce', 'frozen appetizers sides', 'soup broth bouillon',
#        'dry pasta', 'prepared meals', 'fresh herbs',
#        'hot cereal pancake mixes', 'spices seasonings',
#        'grains rice dried goods', 'frozen breads doughs', 'missing',
#        'popcorn jerky', 'granola', 'muscles joints pain relief',
#        'energy sports drinks', 'crackers', 'candy chocolate',
#        'fruit vegetable snacks', 'tortillas flat bread',
#        'tofu meat alternatives', 'beers coolers', 'laundry',
#        'asian foods', 'frozen meat seafood', 'frozen meals', 'spreads',
#        'mint gum', 'cold flu allergy', 'breakfast bakery',
#        'trail mix snack mix', 'air fresheners candles', 'feminine care',
#        'breakfast bars pastries', 'instant foods', 'spirits',
#        'salad dressing toppings', 'doughs gelatins bake mixes',
#        'oils vinegars', 'baby food formula', 'eye ear care',
#        'dog food care', 'baby accessories', 'frozen pizza',
#        'marinades meat preparation', 'frozen vegan vegetarian',
#        'shave needs', 'specialty wines champagnes', 'cookies cakes',
#        'cleaning products', 'packaged seafood',
#        'bulk grains rice dried goods', 'frozen dessert', 'skin care',
#        'deodorants', 'white wines', 'protein meal replacements',
#        'canned meat seafood', 'digestion', 'trash bags liners',
#        'refrigerated pudding desserts', 'specialty cheeses',
#        'bulk dried fruits vegetables', 'red wines', 'body lotions soap',
#        'hair care', 'vitamins supplements', 'cocoa drink mixes',
#        'first aid', 'dish detergents', 'packaged meat', 'other',
#        'cat food care', 'indian foods', 'baking supplies decor',
#        'seafood counter', 'ice cream toppings', 'baby bath body care',
#        'more household', 'kosher foods', 'facial care',
#        'kitchen supplies', 'beauty', 'frozen juice'], dtype=object)

# %%
# TAKING CARE OF NULL VALUES
for col in df.columns:
    if df[col].dtypes == 'float64':
        df[col].fillna(-1,inplace=True)

# %%
all_transactions = [transaction[1]['product_name'].tolist() for transaction in list(df.groupby(['order_id', 'user_id']))]

# %%
df1 = df[['order_id','user_id','product_name']].drop_duplicates()

# %%
df1.head(20)
# Out:
#     order_id  user_id        product_name
# 0    2425083    49125  baking ingredients
# 1    2425083    49125     soy lactosefree
# 2    2425083    49125              butter
# 3    2425083    49125    fresh vegetables
# 6    2425083    49125              yogurt
# 7    2425083    49125  canned meals beans
# 8    2425083    49125     poultry counter
# 9    1944304   162867       ice cream ice
# 10   1944304   162867        fresh fruits
# 11   1944304   162867    fresh vegetables
# 12   1944304   162867                milk
# 13   1944304   162867     soy lactosefree
# 17   1944304   162867     packaged cheese
# 18   1944304   162867               bread
# 22   1201011   147243                 tea
# 23   1201011   147243    fresh vegetables
# 25   1201011   147243        fresh fruits
# 26   1201011   147243              yogurt
# 28   1201011   147243     soy lactosefree
# 31   1201011   147243     bakery desserts

# %%
newcol = {'order_id':'Invoice','user_id':'Member_number','product_name':'itemDescription'}
df1.rename(columns=newcol, inplace = True)
df1.head(5)
# Out:
#    Invoice  Member_number     itemDescription
# 0  2425083          49125  baking ingredients
# 1  2425083          49125     soy lactosefree
# 2  2425083          49125              butter
# 3  2425083          49125    fresh vegetables
# 6  2425083          49125              yogurt

# %%
all_transactions = [transaction[1]['itemDescription'].tolist() for transaction in list(df1.groupby(['Member_number', 'Invoice']))]
all_transactions[0:5]
# Out:
# [['fresh fruits',
#   'packaged cheese',
#   'crackers',
#   'chips pretzels',
#   'fresh dips tapenades'],
#  ['fresh fruits',
#   'popcorn jerky',
#   'lunch meat',
#   'packaged cheese',
#   'prepared soups salads'],
#  ['other creams cheeses',
#   'packaged vegetables fruits',
#   'nuts seeds dried fruit',
#   'packaged cheese',
#   'paper goods',
#   'soy lactosefree',
#   'fresh fruits',
#   'water seltzer sparkling water',
#   'crackers'],
#  ['soy lactosefree', 'fresh fruits', 'packaged vegetables fruits'],
#  ['spreads',
#   'nuts seeds dried fruit',
#   'fresh fruits',
#   'ice cream ice',
#   'frozen breakfast']]

# %%
# The following instructions transform the dataset into the required format 
trans_encoder = TransactionEncoder() # Instanciate the encoder
trans_encoder_matrix = trans_encoder.fit(all_transactions).transform(all_transactions)
trans_encoder_matrix = pd.DataFrame(trans_encoder_matrix, columns=trans_encoder.columns_)

# %%
trans_encoder_matrix.head()
# Out:
#    air fresheners candles  asian foods  baby accessories  baby bath body care
# 0                   False        False             False                False  \
# 1                   False        False             False                False
# 2                   False        False             False                False
# 3                   False        False             False                False
# 4                   False        False             False                False
#
#    baby food formula  bakery desserts  baking ingredients
# 0              False            False               False  \
# 1              False            False               False
# 2              False            False               False
# 3              False            False               False
# 4              False            False               False
#
#    baking supplies decor  beauty  beers coolers  ...  spreads    tea
# 0                  False   False          False  ...    False  False  \
# 1                  False   False          False  ...    False  False
# 2                  False   False          False  ...    False  False
# 3                  False   False          False  ...    False  False
# 4                  False   False          False  ...     True  False
#
#    tofu meat alternatives  tortillas flat bread  trail mix snack mix
# 0                   False                 False                False  \
# 1                   False                 False                False
# 2                   False                 False                False
# 3                   False                 False                False
# 4                   False                 False                False
#
#    trash bags liners  vitamins supplements  water seltzer sparkling water
# 0              False                 False                          False  \
# 1              False                 False                          False
# 2              False                 False                           True
# 3              False                 False                          False
# 4              False                 False                          False
#
#    white wines  yogurt
# 0        False   False
# 1        False   False
# 2        False   False
# 3        False   False
# 4        False   False
#
# [5 rows x 134 columns]

# %%
def perform_rule_calculation(transact_items_matrix, rule_type="fpgrowth", min_support=0.01):
    """
    desc: this function performs the association rule calculation 
    @params:
        - transact_items_matrix: the transaction X Items matrix
        - rule_type: 
                    - apriori or Growth algorithms (default="fpgrowth")
                    
        - min_support: minimum support threshold value (default = 0.001)
        
    @returns:
        - the matrix containing 3 columns:
            - support: support values for each combination of items
            - itemsets: the combination of items
            - number_of_items: the number of items in each combination of items
            
        - the excution time for the corresponding algorithm
        
    """
    start_time = 0
    total_execution = 0
    
    if(not rule_type=="fpgrowth"):
        start_time = time.time()
        rule_items = apriori(transact_items_matrix, 
                       min_support=min_support, 
                       use_colnames=True)
        total_execution = time.time() - start_time
        print("Computed Apriori!")
        
    else:
        start_time = time.time()
        rule_items = fpgrowth(transact_items_matrix, 
                       min_support=min_support, 
                       use_colnames=True)
        total_execution = time.time() - start_time
        print("Computed Fp Growth!")
    
    rule_items['number_of_items'] = rule_items['itemsets'].apply(lambda x: len(x))
    
    return rule_items, total_execution

# %%
def compute_association_rule(rule_matrix, metric="lift", min_thresh=1):
    """
    @desc: Compute the final association rule
    @params:
        - rule_matrix: the corresponding algorithms matrix
        - metric: the metric to be used (default is lift)
        - min_thresh: the minimum threshold (default is 1)
        
    @returns:
        - rules: all the information for each transaction satisfying the given metric & threshold
    """
    rules = association_rules(rule_matrix, 
                              metric=metric, 
                              min_threshold=min_thresh)
    
    return rules

# %%
def plot_metrics_relationship(rule_matrix, col1, col2):
    """
    desc: shows the relationship between the two input columns 
    @params:
        - rule_matrix: the matrix containing the result of a rule (apriori or Fp Growth)
        - col1: first column
        - col2: second column
    """
    fit = np.polyfit(rule_matrix[col1], rule_matrix[col2], 1)
    fit_funt = np.poly1d(fit)
    plt.plot(rule_matrix[col1], rule_matrix[col2], 'yo', rule_matrix[col1], 
    fit_funt(rule_matrix[col1]))
    plt.xlabel(col1)
    plt.ylabel(col2)
    plt.title('{} vs {}'.format(col1, col2))
def compare_time_exec(algo1=list, alg2=list):
    """
    @desc: shows the execution time between two algorithms
    @params:
        - algo1: list containing the description of first algorithm, where
            
        - algo2: list containing the description of second algorithm, where
    """
    
    execution_times = [algo1[1], algo2[1]]
    algo_names = (algo1[0], algo2[0])
    y=np.arange(len(algo_names))
    
    plt.bar(y,execution_times,color=['orange', 'blue'])
    plt.xticks(y,algo_names)
    plt.xlabel('Algorithms')
    plt.ylabel('Time')
    plt.title("Execution Time (seconds) Comparison")
    plt.show()

# %%
val = {'name':12}
value = list(val.items())[0]
value
# Out:
# ('name', 12)

# %%
fpgrowth_matrix, fp_growth_exec_time = perform_rule_calculation(trans_encoder_matrix) # Run the algorithm
print("Fp Growth execution took: {} seconds".format(fp_growth_exec_time))
# Out:
# Computed Fp Growth!
# Fp Growth execution took: 19.035372018814087 seconds

# %%
fpgrowth_matrix.head()
# Out:
#     support                itemsets  number_of_items
# 0  0.555995          (fresh fruits)                1
# 1  0.230995       (packaged cheese)                1
# 2  0.169435        (chips pretzels)                1
# 3  0.114970              (crackers)                1
# 4  0.098205  (fresh dips tapenades)                1

# %%
fpgrowth_matrix.tail()
# Out:
#        support                                           itemsets
# 2924  0.010215               (specialty cheeses, packaged cheese)  \
# 2925  0.012100  (specialty cheeses, fresh vegetables, fresh fr...
# 2926  0.013325                  (fresh fruits, cleaning products)
# 2927  0.010420              (fresh vegetables, cleaning products)
# 2928  0.011180                               (fresh fruits, soap)
#
#       number_of_items
# 2924                2
# 2925                3
# 2926                2
# 2927                2
# 2928                2

# %%
fp_growth_rule_lift = compute_association_rule(fpgrowth_matrix)
fp_growth_rule_lift.head(10)
# Out:
#                     antecedents                   consequents
# 0             (packaged cheese)                (fresh fruits)  \
# 1                (fresh fruits)             (packaged cheese)
# 2             (packaged cheese)  (packaged vegetables fruits)
# 3  (packaged vegetables fruits)             (packaged cheese)
# 4            (fresh vegetables)             (packaged cheese)
# 5             (packaged cheese)            (fresh vegetables)
# 6             (packaged cheese)                      (yogurt)
# 7                      (yogurt)             (packaged cheese)
# 8             (packaged cheese)                        (milk)
# 9                        (milk)             (packaged cheese)
#
#    antecedent support  consequent support  support  confidence      lift
# 0            0.230995            0.555995  0.15590    0.674906  1.213871  \
# 1            0.555995            0.230995  0.15590    0.280398  1.213871
# 2            0.230995            0.365415  0.11461    0.496158  1.357793
# 3            0.365415            0.230995  0.11461    0.313643  1.357793
# 4            0.444360            0.230995  0.13585    0.305721  1.323494
# 5            0.230995            0.444360  0.13585    0.588108  1.323494
# 6            0.230995            0.263675  0.08852    0.383212  1.453349
# 7            0.263675            0.230995  0.08852    0.335716  1.453349
# 8            0.230995            0.243325  0.07817    0.338406  1.390756
# 9            0.243325            0.230995  0.07817    0.321258  1.390756
#
#    leverage  conviction  zhangs_metric
# 0  0.027468    1.365776       0.229114
# 1  0.027468    1.068654       0.396819
# 2  0.030201    1.259492       0.342664
# 3  0.030201    1.120416       0.415249
# 4  0.033205    1.107630       0.439897
# 5  0.033205    1.348994       0.317845
# 6  0.027612    1.193805       0.405633
# 7  0.027612    1.157645       0.423636
# 8  0.021963    1.143714       0.365364
# 9  0.021963    1.132985       0.371317

# %%
fp_growth_rule = compute_association_rule(fpgrowth_matrix, metric="confidence", min_thresh=0.2)
fp_growth_rule.head(5)
# Out:
#                     antecedents                   consequents
# 0             (packaged cheese)                (fresh fruits)  \
# 1                (fresh fruits)             (packaged cheese)
# 2             (packaged cheese)  (packaged vegetables fruits)
# 3  (packaged vegetables fruits)             (packaged cheese)
# 4            (fresh vegetables)             (packaged cheese)
#
#    antecedent support  consequent support  support  confidence      lift
# 0            0.230995            0.555995  0.15590    0.674906  1.213871  \
# 1            0.555995            0.230995  0.15590    0.280398  1.213871
# 2            0.230995            0.365415  0.11461    0.496158  1.357793
# 3            0.365415            0.230995  0.11461    0.313643  1.357793
# 4            0.444360            0.230995  0.13585    0.305721  1.323494
#
#    leverage  conviction  zhangs_metric
# 0  0.027468    1.365776       0.229114
# 1  0.027468    1.068654       0.396819
# 2  0.030201    1.259492       0.342664
# 3  0.030201    1.120416       0.415249
# 4  0.033205    1.107630       0.439897

# %%
fp_growth_rule[['antecedents', 'consequents','support']].head(5)
# Out:
#                     antecedents                   consequents  support
# 0             (packaged cheese)                (fresh fruits)  0.15590
# 1                (fresh fruits)             (packaged cheese)  0.15590
# 2             (packaged cheese)  (packaged vegetables fruits)  0.11461
# 3  (packaged vegetables fruits)             (packaged cheese)  0.11461
# 4            (fresh vegetables)             (packaged cheese)  0.13585

# %%
#fp_growth_rule['antecedents'].info()
fp_growth_rule.iloc[48,0] == frozenset({'packaged cheese'})
#fp_growth_rule.head(10)
fp_growth_rule['antecedents'] = fp_growth_rule['antecedents'].apply(lambda x:list(x))
#pip install fuzzywuzzy

# %%
fp_growth_rule.head(25)
# Out:
#                                           antecedents
# 0                                   [packaged cheese]  \
# 1                                      [fresh fruits]
# 2                                   [packaged cheese]
# 3                        [packaged vegetables fruits]
# 4                                  [fresh vegetables]
# 5                                   [packaged cheese]
# 6                                   [packaged cheese]
# 7                                            [yogurt]
# 8                                   [packaged cheese]
# 9                                              [milk]
# 10                    [packaged cheese, fresh fruits]
# 11      [packaged cheese, packaged vegetables fruits]
# 12         [fresh fruits, packaged vegetables fruits]
# 13                                  [packaged cheese]
# 14                       [packaged vegetables fruits]
# 15                [fresh vegetables, packaged cheese]
# 16     [fresh vegetables, packaged vegetables fruits]
# 17      [packaged cheese, packaged vegetables fruits]
# 18                                  [packaged cheese]
# 19                       [packaged vegetables fruits]
# 20  [fresh vegetables, packaged cheese, fresh fruits]
# 21  [fresh vegetables, packaged cheese, packaged v...
# 22  [fresh vegetables, fresh fruits, packaged vege...
# 23  [packaged cheese, fresh fruits, packaged veget...
# 24                [fresh vegetables, packaged cheese]
#
#                                        consequents  antecedent support
# 0                                   (fresh fruits)            0.230995  \
# 1                                (packaged cheese)            0.555995
# 2                     (packaged vegetables fruits)            0.230995
# 3                                (packaged cheese)            0.365415
# 4                                (packaged cheese)            0.444360
# 5                               (fresh vegetables)            0.230995
# 6                                         (yogurt)            0.230995
# 7                                (packaged cheese)            0.263675
# 8                                           (milk)            0.230995
# 9                                (packaged cheese)            0.243325
# 10                    (packaged vegetables fruits)            0.155900
# 11                                  (fresh fruits)            0.114610
# 12                               (packaged cheese)            0.269870
# 13      (fresh fruits, packaged vegetables fruits)            0.230995
# 14                 (packaged cheese, fresh fruits)            0.365415
# 15                    (packaged vegetables fruits)            0.135850
# 16                               (packaged cheese)            0.234555
# 17                              (fresh vegetables)            0.114610
# 18  (fresh vegetables, packaged vegetables fruits)            0.230995
# 19             (fresh vegetables, packaged cheese)            0.365415
# 20                    (packaged vegetables fruits)            0.104570
# 21                                  (fresh fruits)            0.081970
# 22                               (packaged cheese)            0.186580
# 23                              (fresh vegetables)            0.090715
# 24      (fresh fruits, packaged vegetables fruits)            0.135850
#
#     consequent support   support  confidence      lift  leverage  conviction
# 0             0.555995  0.155900    0.674906  1.213871  0.027468    1.365776  \
# 1             0.230995  0.155900    0.280398  1.213871  0.027468    1.068654
# 2             0.365415  0.114610    0.496158  1.357793  0.030201    1.259492
# 3             0.230995  0.114610    0.313643  1.357793  0.030201    1.120416
# 4             0.230995  0.135850    0.305721  1.323494  0.033205    1.107630
# 5             0.444360  0.135850    0.588108  1.323494  0.033205    1.348994
# 6             0.263675  0.088520    0.383212  1.453349  0.027612    1.193805
# 7             0.230995  0.088520    0.335716  1.453349  0.027612    1.157645
# 8             0.243325  0.078170    0.338406  1.390756  0.021963    1.143714
# 9             0.230995  0.078170    0.321258  1.390756  0.021963    1.132985
# 10            0.365415  0.090715    0.581879  1.592380  0.033747    1.517708
# 11            0.555995  0.090715    0.791510  1.423593  0.026992    2.129626
# 12            0.230995  0.090715    0.336143  1.455197  0.028376    1.158390
# 13            0.269870  0.090715    0.392714  1.455197  0.028376    1.202284
# 14            0.155900  0.090715    0.248252  1.592380  0.033747    1.122850
# 15            0.365415  0.081970    0.603386  1.651235  0.032328    1.600007
# 16            0.230995  0.081970    0.349470  1.512891  0.027789    1.182121
# 17            0.444360  0.081970    0.715208  1.609524  0.031042    1.951039
# 18            0.234555  0.081970    0.354856  1.512891  0.027789    1.186472
# 19            0.135850  0.081970    0.224320  1.651235  0.032328    1.114055
# 20            0.365415  0.068325    0.653390  1.788077  0.030114    1.830833
# 21            0.555995  0.068325    0.833537  1.499180  0.022750    2.667284
# 22            0.230995  0.068325    0.366197  1.585302  0.025226    1.213318
# 23            0.444360  0.068325    0.753183  1.694984  0.028015    2.251223
# 24            0.269870  0.068325    0.502944  1.863654  0.031663    1.468910
#
#     zhangs_metric
# 0        0.229114
# 1        0.396819
# 2        0.342664
# 3        0.415249
# 4        0.439897
# 5        0.317845
# 6        0.405633
# 7        0.423636
# 8        0.365364
# 9        0.371317
# 10       0.440717
# 11       0.336069
# 12       0.428428
# 13       0.406770
# 14       0.586224
# 15       0.456394
# 16       0.442898
# 17       0.427719
# 18       0.440847
# 19       0.621497
# 20       0.492210
# 21       0.362699
# 22       0.453893
# 23       0.450930
# 24       0.536272

# %%
fp_growth_rule['antecedents'] = fp_growth_rule['antecedents'].apply(lambda x:sorted(x))
fp_growth_rule['consequents'] = fp_growth_rule['consequents'].apply(lambda x:sorted(x))
fp_growth_rule.head(25)
# Out:
#                                           antecedents
# 0                                   [packaged cheese]  \
# 1                                      [fresh fruits]
# 2                                   [packaged cheese]
# 3                        [packaged vegetables fruits]
# 4                                  [fresh vegetables]
# 5                                   [packaged cheese]
# 6                                   [packaged cheese]
# 7                                            [yogurt]
# 8                                   [packaged cheese]
# 9                                              [milk]
# 10                    [fresh fruits, packaged cheese]
# 11      [packaged cheese, packaged vegetables fruits]
# 12         [fresh fruits, packaged vegetables fruits]
# 13                                  [packaged cheese]
# 14                       [packaged vegetables fruits]
# 15                [fresh vegetables, packaged cheese]
# 16     [fresh vegetables, packaged vegetables fruits]
# 17      [packaged cheese, packaged vegetables fruits]
# 18                                  [packaged cheese]
# 19                       [packaged vegetables fruits]
# 20  [fresh fruits, fresh vegetables, packaged cheese]
# 21  [fresh vegetables, packaged cheese, packaged v...
# 22  [fresh fruits, fresh vegetables, packaged vege...
# 23  [fresh fruits, packaged cheese, packaged veget...
# 24                [fresh vegetables, packaged cheese]
#
#                                        consequents  antecedent support
# 0                                   [fresh fruits]            0.230995  \
# 1                                [packaged cheese]            0.555995
# 2                     [packaged vegetables fruits]            0.230995
# 3                                [packaged cheese]            0.365415
# 4                                [packaged cheese]            0.444360
# 5                               [fresh vegetables]            0.230995
# 6                                         [yogurt]            0.230995
# 7                                [packaged cheese]            0.263675
# 8                                           [milk]            0.230995
# 9                                [packaged cheese]            0.243325
# 10                    [packaged vegetables fruits]            0.155900
# 11                                  [fresh fruits]            0.114610
# 12                               [packaged cheese]            0.269870
# 13      [fresh fruits, packaged vegetables fruits]            0.230995
# 14                 [fresh fruits, packaged cheese]            0.365415
# 15                    [packaged vegetables fruits]            0.135850
# 16                               [packaged cheese]            0.234555
# 17                              [fresh vegetables]            0.114610
# 18  [fresh vegetables, packaged vegetables fruits]            0.230995
# 19             [fresh vegetables, packaged cheese]            0.365415
# 20                    [packaged vegetables fruits]            0.104570
# 21                                  [fresh fruits]            0.081970
# 22                               [packaged cheese]            0.186580
# 23                              [fresh vegetables]            0.090715
# 24      [fresh fruits, packaged vegetables fruits]            0.135850
#
#     consequent support   support  confidence      lift  leverage  conviction
# 0             0.555995  0.155900    0.674906  1.213871  0.027468    1.365776  \
# 1             0.230995  0.155900    0.280398  1.213871  0.027468    1.068654
# 2             0.365415  0.114610    0.496158  1.357793  0.030201    1.259492
# 3             0.230995  0.114610    0.313643  1.357793  0.030201    1.120416
# 4             0.230995  0.135850    0.305721  1.323494  0.033205    1.107630
# 5             0.444360  0.135850    0.588108  1.323494  0.033205    1.348994
# 6             0.263675  0.088520    0.383212  1.453349  0.027612    1.193805
# 7             0.230995  0.088520    0.335716  1.453349  0.027612    1.157645
# 8             0.243325  0.078170    0.338406  1.390756  0.021963    1.143714
# 9             0.230995  0.078170    0.321258  1.390756  0.021963    1.132985
# 10            0.365415  0.090715    0.581879  1.592380  0.033747    1.517708
# 11            0.555995  0.090715    0.791510  1.423593  0.026992    2.129626
# 12            0.230995  0.090715    0.336143  1.455197  0.028376    1.158390
# 13            0.269870  0.090715    0.392714  1.455197  0.028376    1.202284
# 14            0.155900  0.090715    0.248252  1.592380  0.033747    1.122850
# 15            0.365415  0.081970    0.603386  1.651235  0.032328    1.600007
# 16            0.230995  0.081970    0.349470  1.512891  0.027789    1.182121
# 17            0.444360  0.081970    0.715208  1.609524  0.031042    1.951039
# 18            0.234555  0.081970    0.354856  1.512891  0.027789    1.186472
# 19            0.135850  0.081970    0.224320  1.651235  0.032328    1.114055
# 20            0.365415  0.068325    0.653390  1.788077  0.030114    1.830833
# 21            0.555995  0.068325    0.833537  1.499180  0.022750    2.667284
# 22            0.230995  0.068325    0.366197  1.585302  0.025226    1.213318
# 23            0.444360  0.068325    0.753183  1.694984  0.028015    2.251223
# 24            0.269870  0.068325    0.502944  1.863654  0.031663    1.468910
#
#     zhangs_metric
# 0        0.229114
# 1        0.396819
# 2        0.342664
# 3        0.415249
# 4        0.439897
# 5        0.317845
# 6        0.405633
# 7        0.423636
# 8        0.365364
# 9        0.371317
# 10       0.440717
# 11       0.336069
# 12       0.428428
# 13       0.406770
# 14       0.586224
# 15       0.456394
# 16       0.442898
# 17       0.427719
# 18       0.440847
# 19       0.621497
# 20       0.492210
# 21       0.362699
# 22       0.453893
# 23       0.450930
# 24       0.536272

# %%
fp_growth_rule['antecedents'] = fp_growth_rule['antecedents'].apply(lambda x:set(x))
fp_growth_rule.head(25)
fp_growth_rule.to_csv('C:\\Users\\vc185080\\Downloads\\Retail_Proj\\Output.csv',index=False)

# %%
# Out:
# 5
# first loop
# basket =  {'cat food care', 'packaged cheese', 'dish detergents', 'fresh fruits', 'packaged vegetables fruits'} recommendation = []
# second loop
# third loop
# max length =  3
# [['fresh dips tapenades'], ['fresh vegetables'], ['fresh vegetables', 'soy lactosefree'], ['soy lactosefree'], ['water seltzer sparkling water']]  ---> {'fresh dips tapenades', 'soy lactosefree', 'water seltzer sparkling water', 'fresh vegetables'}
# basket =  {'cat food care', 'packaged cheese', 'dish detergents', 'fresh fruits', 'packaged vegetables fruits'} recommendation = ['fresh vegetables', 'yogurt']
